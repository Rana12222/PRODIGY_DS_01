# %% [markdown]
# <a href="https://colab.research.google.com/github/Rana12222/PRODIGY_DS_01/blob/main/TASK01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import style

# %%
df=pd.read_csv('/content/SAMPLE.csv')
df.head()
# Out:
#   Country Name Country Code      AGES         GENDER  Year      Value  \
# 0  Afghanistan          AFG  ALL AGES  MALES+FEMALES  1993  73.234001
# 1  Afghanistan          AFG  ALL AGES  MALES+FEMALES  1974  73.177788
# 2      Albania          ALB  ALL AGES  MALES+FEMALES  2021   7.804900
# 3      Albania          ALB  ALL AGES  MALES+FEMALES  2020   3.841930
# 4      Albania          ALB  ALL AGES  MALES+FEMALES  2019   2.106890
#
#    FLAG CODES  FLAGS
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN

# %%
df.shape
# Out:
# (167532, 8)

# %%
df.isnull().sum()
# Out:
# Country Name         0
# Country Code         0
# AGES                 0
# GENDER               0
# Year                 0
# Value                0
# FLAG CODES      167532
# FLAGS           167532
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
country=['India','Sri Lanka','Australia','London','France']
population=[1854947,16499054,5811432,989216,9415639]
plt.figure(figsize=(5,4))
plt.bar(country,population,color='Skyblue')
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Total Population By Country')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Age=['0-4 years','5-14 years','15-24 years','25-64 years','65+']
Country=['India','Sri Lanka','Australia','London','France']
plt.figure(figsize=(5,3))
plt.bar(Country,Age,color='orange')
plt.xlabel('Country')
plt.ylabel('Age')
plt.title('Age Distribution')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Age=['0-4 years','5-14 years','15-24 years','25-64 years','65+']
Country=['India','Sri Lanka','Australia','London','France']
population=[1854947,16499004,5811432,989216,9415639]
fig , ax1=plt.subplots(figsize=(7,4))
ax1.bar(Country,population,color='skyblue')
ax1.set_xlabel('Country')
ax1.set_ylabel('Total Population',color='skyblue')
ax1.tick_params(axis='y',labelcolor='skyblue')
ax2=ax1.twinx()
ax2.plot(Country,Age,marker='o',color='orange',linestyle='-',linewidth=2)
ax2.set_ylabel('Average Age',color='orange')
ax2.tick_params(axis='y',labelcolor='orange')
plt.title('Age Distribution in Total Population')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
